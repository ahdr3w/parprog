# %%
import matplotlib.pyplot as plot
from mpl_toolkits.mplot3d import Axes3D
import numpy as np


n = [1, 2, 3, 4, 5, 6, 7, 8]
k = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000]
t0 = [0.730945, 2.04087, 3.2801, 4.46292, 5.58905, 6.74808, 7.89107, 9.10777, 10.2767, 11.9129]
t1 = [0.759541, 2.07248, 3.33874, 4.53191, 5.70354, 6.88927, 8.05608, 9.31235, 10.5082, 11.8198]
t2 = [0.37625, 0.773325, 1.35498, 2.13978, 2.85562, 3.45616, 4.04057, 4.67709, 5.33221, 5.97914]
t3 = [0.281301, 0.57319, 0.825295, 1.41084, 1.77464, 2.34011, 2.83636, 3.43002, 3.89618, 4.36006]
t4 = [0.282806, 0.483737, 0.815428, 1.23731, 1.37549, 1.92316, 2.37952, 2.79987, 3.28931, 3.73728]
t5 = [0.21433, 0.431982, 0.636808, 0.950402, 1.30464, 1.6445, 2.05232, 2.35111, 2.78294, 3.16957]
t6 = [0.221415, 0.426283, 0.664542, 0.926327, 1.27255, 1.63226, 2.01244, 2.31966, 2.67747, 3.04053]
t7 = [0.198645, 0.402708, 0.596352, 0.828932, 1.13817, 1.47536, 1.8492, 2.21504, 2.54298, 2.86651]
t8 = [0.180625, 0.375563, 0.573511, 0.788326, 1.04554, 1.33937, 1.71905, 2.08432, 2.37515, 2.7779]


fig = plot.figure(figsize = (15, 10))
for i in k:
  plot.plot(n, [ t1[i//1000-1], t2[i//1000-1], t3[i//1000-1], t4[i//1000-1], t5[i//1000-1], t6[i//1000-1], t7[i//1000-1], t8[i//1000-1] ])

plot.title('Зависимость времени от числа исполнителей')
plot.xlim(1, 8)
plot.xlabel('$p$ ,количество исполнителей')
plot.ylabel('$t$ ,время исполнения')
plot.grid()
fig.savefig('execution.png', dpi = 300)

fig = plot.figure(figsize = (15, 10))
for i in k:
  plot.plot(n, [ t0[i//1000-1]/t1[i//1000-1], t0[i//1000-1]/t2[i//1000-1], t0[i//1000-1]/t3[i//1000-1], t0[i//1000-1]/t4[i//1000-1], t0[i//1000-1]/t5[i//1000-1], 
               t0[i//1000-1]/t6[i//1000-1], t0[i//1000-1]/t7[i//1000-1], t0[i//1000-1]/t8[i//1000-1] ])

plot.title('Зависимость ускорения от числа исполнителей')
plot.xlim(1, 8)
plot.xlabel('$p$ ,количество исполнителей')
plot.ylabel('$S$ ,ускорение')
plot.grid()

fig.savefig('acceleration.png', dpi = 300)

fig = plot.figure(figsize = (15, 10))

for i in k:
  plot.plot(n, [ t0[i//1000-1]/t1[i//1000-1]/1, t0[i//1000-1]/t2[i//1000-1]/2, t0[i//1000-1]/t3[i//1000-1]/3, t0[i//1000-1]/t4[i//1000-1]/4, t0[i//1000-1]/t5[i//1000-1]/5, 
               t0[i//1000-1]/t6[i//1000-1]/6, t0[i//1000-1]/t7[i//1000-1]/7, t0[i//1000-1]/t8[i//1000-1]/8 ])

plot.title('Зависимость эффективности от числа исполнителей')
plot.xlim(1, 8)
plot.xlabel('$p$ ,количество исполнителей')
plot.ylabel('$E$ ,эффективность')
plot.grid()
fig.savefig('effectiveness.png', dpi = 300)
